# %%
# 1.1 Generate a list of 100 simulated sensor readings.
#    Each reading should be a tuple: (timestamp_str, device_id, device_type, location, value).
#    - timestamp_str: Format as 'YYYY-MM-DD HH:MM:SS'
#    - device_id: A unique ID for each reading (e.g., 'DEV001', 'DEV002', etc., up to 100 unique IDs).
#    - device_type: Randomly chosen from DEVICE_TYPES.
#    - location: Randomly chosen from LOCATIONS.
#    - value: Random float within READING_RANGES for its device_type (round to 2 decimal places).
# Store these in a list called 'raw_sensor_data'.

# Your code for Task 1.1 here:
import random
from datetime import datetime, timedelta

raw_sensor_data = []

DEVICE_TYPES = ["Temperature", "Humidity", "Pressure", "Light"]
LOCATIONS = ["Room A", "Room B", "Room C", "Outdoor"]

READING_RANGES = {
    "Temperature": (20.0, 40.0),
    "Humidity": (30.0, 90.0),
    "Pressure": (950.0, 1050.0),
    "Light": (100.0, 1000.0)
}

start_time = datetime.now()

for i in range(1, 101):
    device_type = random.choice(DEVICE_TYPES)
    location = random.choice(LOCATIONS)

    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    timestamp = start_time + timedelta(seconds=i)

    reading = (
        timestamp.strftime("%Y-%m-%d %H:%M:%S"),
        f"DEV{i:03d}",
        device_type,
        location,
        value
    )

    raw_sensor_data.append(reading)

print(raw_sensor_data)
# Out:
# [('2026-08-13 07:59:30', 'DEV001', 'Light', 'Room B', 460.46), ('2026-08-13 07:59:31', 'DEV002', 'Pressure', 'Outdoor', 1027.56), ('2026-08-13 07:59:32', 'DEV003', 'Temperature', 'Room B', 32.66), ('2026-08-13 07:59:33', 'DEV004', 'Pressure', 'Room B', 1023.19), ('2026-08-13 07:59:34', 'DEV005', 'Pressure', 'Outdoor', 1015.57), ('2026-08-13 07:59:35', 'DEV006', 'Pressure', 'Outdoor', 1027.24), ('2026-08-13 07:59:36', 'DEV007', 'Temperature', 'Room B', 36.75), ('2026-08-13 07:59:37', 'DEV008', 'Humidity', 'Outdoor', 32.19), ('2026-08-13 07:59:38', 'DEV009', 'Light', 'Room B', 955.27), ('2026-08-13 07:59:39', 'DEV010', 'Temperature', 'Room A', 39.88), ('2026-08-13 07:59:40', 'DEV011', 'Humidity', 'Outdoor', 79.83), ('2026-08-13 07:59:41', 'DEV012', 'Temperature', 'Room A', 31.62), ('2026-08-13 07:59:42', 'DEV013', 'Humidity', 'Room A', 35.75), ('2026-08-13 07:59:43', 'DEV014', 'Pressure', 'Outdoor', 1037.87), ('2026-08-13 07:59:44', 'DEV015', 'Humidity', 'Room C', 58.84), ('2026-08-13 07:59:45', 'DEV016', 'Temperature', 'Room A', 29.33), ('2026-08-13 07:59:46', 'DEV017', 'Temperature', 'Room C', 39.58), ('2026-08-13 07:59:47', 'DEV018', 'Pressure', 'Room B', 1015.18), ('2026-08-13 07:59:48', 'DEV019', 'Humidity', 'Room C', 78.77), ('2026-08-13 07:59:49', 'DEV020', 'Light', 'Outdoor', 585.83), ('2026-08-13 07:59:50', 'DEV021', 'Temperature', 'Room C', 22.41), ('2026-08-13 07:59:51', 'DEV022', 'Light', 'Room B', 855.63), ('2026-08-13 07:59:52', 'DEV023', 'Humidity', 'Outdoor', 66.87), ('2026-08-13 07:59:53', 'DEV024', 'Temperature', 'Room C', 33.48), ('2026-08-13 07:59:54', 'DEV025', 'Humidity', 'Room B', 75.29), ('2026-08-13 07:59:55', 'DEV026', 'Humidity', 'Outdoor', 40.8), ('2026-08-13 07:59:56', 'DEV027', 'Humidity', 'Room C', 34.44), ('2026-08-13 07:59:57', 'DEV028', 'Humidity', 'Room B', 50.94), ('2026-08-13 07:59:58', 'DEV029', 'Light', 'Room A', 817.43), ('2026-08-13 07:59:59', 'DEV030', 'Humidity', 'Room B', 38.31), ('2026-08-13 08:00:00', 'DEV031', 'Pressure', 'Room C', 952.5), ('2026-08-13 08:00:01', 'DEV032', 'Humidity', 'Room B', 60.46), ('2026-08-13 08:00:02', 'DEV033', 'Temperature', 'Room B', 36.9), ('2026-08-13 08:00:03', 'DEV034', 'Temperature', 'Room B', 35.76), ('2026-08-13 08:00:04', 'DEV035', 'Pressure', 'Outdoor', 967.46), ('2026-08-13 08:00:05', 'DEV036', 'Pressure', 'Room C', 995.86), ('2026-08-13 08:00:06', 'DEV037', 'Humidity', 'Room C', 86.78), ('2026-08-13 08:00:07', 'DEV038', 'Humidity', 'Outdoor', 48.19), ('2026-08-13 08:00:08', 'DEV039', 'Temperature', 'Room B', 32.73), ('2026-08-13 08:00:09', 'DEV040', 'Humidity', 'Room A', 66.61), ('2026-08-13 08:00:10', 'DEV041', 'Pressure', 'Room A', 979.65), ('2026-08-13 08:00:11', 'DEV042', 'Light', 'Room B', 436.96), ('2026-08-13 08:00:12', 'DEV043', 'Pressure', 'Room A', 988.08), ('2026-08-13 08:00:13', 'DEV044', 'Temperature', 'Room C', 39.03), ('2026-08-13 08:00:14', 'DEV045', 'Pressure', 'Outdoor', 978.63), ('2026-08-13 08:00:15', 'DEV046', 'Light', 'Room B', 696.44), ('2026-08-13 08:00:16', 'DEV047', 'Pressure', 'Room A', 976.18), ('2026-08-13 08:00:17', 'DEV048', 'Light', 'Room A', 516.85), ('2026-08-13 08:00:18', 'DEV049', 'Temperature', 'Room A', 20.26), ('2026-08-13 08:00:19', 'DEV050', 'Pressure', 'Room B', 966.06), ('2026-08-13 08:00:20', 'DEV051', 'Humidity', 'Room A', 87.62), ('2026-08-13 08:00:21', 'DEV052', 'Light', 'Room C', 718.7), ('2026-08-13 08:00:22', 'DEV053', 'Pressure', 'Room B', 979.81), ('2026-08-13 08:00:23', 'DEV054', 'Humidity', 'Room A', 34.09), ('2026-08-13 08:00:24', 'DEV055', 'Humidity', 'Room B', 84.04), ('2026-08-13 08:00:25', 'DEV056', 'Humidity', 'Room B', 41.46), ('2026-08-13 08:00:26', 'DEV057', 'Temperature', 'Room A', 39.8), ('2026-08-13 08:00:27', 'DEV058', 'Pressure', 'Room C', 1023.45), ('2026-08-13 08:00:28', 'DEV059', 'Pressure', 'Room C', 992.67), ('2026-08-13 08:00:29', 'DEV060', 'Light', 'Room B', 248.46), ('2026-08-13 08:00:30', 'DEV061', 'Pressure', 'Room A', 983.56), ('2026-08-13 08:00:31', 'DEV062', 'Temper ...

# %%
# 1.2 From 'raw_sensor_data', create a list named 'temperature_readings' containing only the readings
#     where 'device_type' is 'Temperature'.
#     Each item in 'temperature_readings' should be a dictionary with keys:
#     'timestamp', 'device_id', 'location', 'temperature_celsius'.
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature": # Corrected from "Temperature_Sensor"
        temperature_readings.append({
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        })

print(temperature_readings)
# Out:
# [{'timestamp': '2026-08-13 07:59:32', 'device_id': 'DEV003', 'location': 'Room B', 'temperature_celsius': 32.66}, {'timestamp': '2026-08-13 07:59:36', 'device_id': 'DEV007', 'location': 'Room B', 'temperature_celsius': 36.75}, {'timestamp': '2026-08-13 07:59:39', 'device_id': 'DEV010', 'location': 'Room A', 'temperature_celsius': 39.88}, {'timestamp': '2026-08-13 07:59:41', 'device_id': 'DEV012', 'location': 'Room A', 'temperature_celsius': 31.62}, {'timestamp': '2026-08-13 07:59:45', 'device_id': 'DEV016', 'location': 'Room A', 'temperature_celsius': 29.33}, {'timestamp': '2026-08-13 07:59:46', 'device_id': 'DEV017', 'location': 'Room C', 'temperature_celsius': 39.58}, {'timestamp': '2026-08-13 07:59:50', 'device_id': 'DEV021', 'location': 'Room C', 'temperature_celsius': 22.41}, {'timestamp': '2026-08-13 07:59:53', 'device_id': 'DEV024', 'location': 'Room C', 'temperature_celsius': 33.48}, {'timestamp': '2026-08-13 08:00:02', 'device_id': 'DEV033', 'location': 'Room B', 'temperature_celsius': 36.9}, {'timestamp': '2026-08-13 08:00:03', 'device_id': 'DEV034', 'location': 'Room B', 'temperature_celsius': 35.76}, {'timestamp': '2026-08-13 08:00:08', 'device_id': 'DEV039', 'location': 'Room B', 'temperature_celsius': 32.73}, {'timestamp': '2026-08-13 08:00:13', 'device_id': 'DEV044', 'location': 'Room C', 'temperature_celsius': 39.03}, {'timestamp': '2026-08-13 08:00:18', 'device_id': 'DEV049', 'location': 'Room A', 'temperature_celsius': 20.26}, {'timestamp': '2026-08-13 08:00:26', 'device_id': 'DEV057', 'location': 'Room A', 'temperature_celsius': 39.8}, {'timestamp': '2026-08-13 08:00:31', 'device_id': 'DEV062', 'location': 'Room B', 'temperature_celsius': 22.0}, {'timestamp': '2026-08-13 08:00:36', 'device_id': 'DEV067', 'location': 'Room A', 'temperature_celsius': 26.01}, {'timestamp': '2026-08-13 08:00:37', 'device_id': 'DEV068', 'location': 'Room A', 'temperature_celsius': 36.45}, {'timestamp': '2026-08-13 08:00:46', 'device_id': 'DEV077', 'location': 'Room A', 'temperature_celsius': 28.16}, {'timestamp': '2026-08-13 08:00:53', 'device_id': 'DEV084', 'location': 'Room B', 'temperature_celsius': 22.99}, {'timestamp': '2026-08-13 08:00:54', 'device_id': 'DEV085', 'location': 'Room B', 'temperature_celsius': 36.14}, {'timestamp': '2026-08-13 08:01:00', 'device_id': 'DEV091', 'location': 'Room C', 'temperature_celsius': 29.7}, {'timestamp': '2026-08-13 08:01:02', 'device_id': 'DEV093', 'location': 'Room C', 'temperature_celsius': 24.99}, {'timestamp': '2026-08-13 08:01:09', 'device_id': 'DEV100', 'location': 'Room C', 'temperature_celsius': 21.01}]

# %%
# 1.3 Create a set named 'unique_locations' containing all unique locations from 'raw_sensor_data'.
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])

print(unique_locations)
# Out:
# {'Room B', 'Room C', 'Outdoor', 'Room A'}

# %%
# 1.4 Create a dictionary named 'device_stats' where keys are 'device_type' and values are
#     a tuple: (min_value, max_value) observed for that device type across all readings.
#     Initialize with sensible large/small values.
device_stats = {}

for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    if device_type not in device_stats:
        device_stats[device_type] = (float("inf"), float("-inf"))

    min_value, max_value = device_stats[device_type]

    device_stats[device_type] = (
        min(min_value, value),
        max(max_value, value)
    )

print(device_stats)
# Out:
# {'Light': (130.92, 970.06), 'Pressure': (952.5, 1045.8), 'Temperature': (20.26, 39.88), 'Humidity': (30.09, 89.9)}

# %%
# 1.5.1 List Slicing: Extract elements from the 10th to the 20th (inclusive) from 'raw_sensor_data'.
#       Store the result in 'sliced_readings_1'.
#       Then, extract every 5th reading from 'raw_sensor_data' starting from the beginning.
#       Store the result in 'sliced_readings_2'.
# 10th to 20th readings (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

print(sliced_readings_1)
print(sliced_readings_2)
# Out:
# [('2026-08-13 07:59:39', 'DEV010', 'Temperature', 'Room A', 39.88), ('2026-08-13 07:59:40', 'DEV011', 'Humidity', 'Outdoor', 79.83), ('2026-08-13 07:59:41', 'DEV012', 'Temperature', 'Room A', 31.62), ('2026-08-13 07:59:42', 'DEV013', 'Humidity', 'Room A', 35.75), ('2026-08-13 07:59:43', 'DEV014', 'Pressure', 'Outdoor', 1037.87), ('2026-08-13 07:59:44', 'DEV015', 'Humidity', 'Room C', 58.84), ('2026-08-13 07:59:45', 'DEV016', 'Temperature', 'Room A', 29.33), ('2026-08-13 07:59:46', 'DEV017', 'Temperature', 'Room C', 39.58), ('2026-08-13 07:59:47', 'DEV018', 'Pressure', 'Room B', 1015.18), ('2026-08-13 07:59:48', 'DEV019', 'Humidity', 'Room C', 78.77), ('2026-08-13 07:59:49', 'DEV020', 'Light', 'Outdoor', 585.83)]
# [('2026-08-13 07:59:30', 'DEV001', 'Light', 'Room B', 460.46), ('2026-08-13 07:59:35', 'DEV006', 'Pressure', 'Outdoor', 1027.24), ('2026-08-13 07:59:40', 'DEV011', 'Humidity', 'Outdoor', 79.83), ('2026-08-13 07:59:45', 'DEV016', 'Temperature', 'Room A', 29.33), ('2026-08-13 07:59:50', 'DEV021', 'Temperature', 'Room C', 22.41), ('2026-08-13 07:59:55', 'DEV026', 'Humidity', 'Outdoor', 40.8), ('2026-08-13 08:00:00', 'DEV031', 'Pressure', 'Room C', 952.5), ('2026-08-13 08:00:05', 'DEV036', 'Pressure', 'Room C', 995.86), ('2026-08-13 08:00:10', 'DEV041', 'Pressure', 'Room A', 979.65), ('2026-08-13 08:00:15', 'DEV046', 'Light', 'Room B', 696.44), ('2026-08-13 08:00:20', 'DEV051', 'Humidity', 'Room A', 87.62), ('2026-08-13 08:00:25', 'DEV056', 'Humidity', 'Room B', 41.46), ('2026-08-13 08:00:30', 'DEV061', 'Pressure', 'Room A', 983.56), ('2026-08-13 08:00:35', 'DEV066', 'Light', 'Outdoor', 676.31), ('2026-08-13 08:00:40', 'DEV071', 'Humidity', 'Room A', 60.23), ('2026-08-13 08:00:45', 'DEV076', 'Light', 'Room C', 483.78), ('2026-08-13 08:00:50', 'DEV081', 'Humidity', 'Outdoor', 34.48), ('2026-08-13 08:00:55', 'DEV086', 'Humidity', 'Room A', 30.09), ('2026-08-13 08:01:00', 'DEV091', 'Temperature', 'Room C', 29.7), ('2026-08-13 08:01:05', 'DEV096', 'Humidity', 'Room C', 82.2)]

# %%
# 1.5.2 String Slicing
# Define the sample string
sample_string = "Python Programming"

# Extract "Programming"
substring_1 = sample_string[7:18]

# Extract "nohtyP" using slicing
substring_2 = sample_string[5::-1]

print(substring_1)
print(substring_2)
# Out:
# Programming
# nohtyP

# %%
# 1.5.3 Mixed Slicing: Access the 'device_type' of the 5th reading in 'raw_sensor_data' using indexing.
#       Store it in 'fifth_reading_device_type'.
#       Then, from 'fifth_reading_device_type', extract the last 6 characters (e.g., 'Sensor' from 'Temperature_Sensor').
#       Store it in 'device_type_suffix'.
# Extract "Programming"
substring_1 = sample_string[10:21]

# Extract "nohtyP" using slicing
substring_2 = sample_string[16:10:-1]

print(substring_1)
print(substring_2)
# Out:
# gramming
# nimmar
